# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from scipy import stats

# %%
df=pd.read_csv('bonheur_avec_meanyearschooling.csv')

# %%
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption          Region  HDI Rank      Country  \
# ...

# %% [markdown]
# # Regardons les corrélations

# %%
m = np.triu(df.corr())
sns.heatmap(df.corr(), annot =True, mask=m)
# Out:
# <AxesSubplot:>

# %%
sns.displot(data=df, x='Score', y='mean_year_school_2018')
plt.title("Lien entre le nombre d'années passées à l'école et le score du Bonheur")
# Out:
# Text(0.5, 1.0, "Lien entre le nombre d'années passées à l'école et le score du Bonheur")

# %%
sns.set(rc = {'figure.figsize':(10,10)})
sns.scatterplot(data=df, y='Score', x='HDI Rank', color='red', marker='^', hue='Region')
plt.title("Lien entre l'indicateur HDI et le bonheur")
# Out:
# Text(0.5, 1.0, "Lien entre l'indicateur HDI et le bonheur")

# %%
df.sort_values(by='HDI Rank',ascending=False)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 110           114                     Niger  4.628           0.138
# 151           155  Central African Republic  3.083           0.026
# 128           132                      Chad  4.350           0.350
# 141           145                   Burundi  3.775           0.046
# 152           156               South Sudan  2.853           0.306
# ..            ...                       ...    ...             ...
# 72             76                 Hong Kong  5.430           1.438
# 15             16                   Ireland  7.021           1.499
# 5               6               Switzerland  7.480           1.452
# 2               3                    Norway  7.554           1.488
# 108           112                   Somalia  4.668           0.000
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 110           0.774                    0.366                         0.318
# ...

# %%
sns.scatterplot(data=df, y='Overall rank', x='HDI Rank', color='red', marker='8', hue='Region')
plt.title("lien entre le classement du bonheur et celui du HDI")
# Out:
# Text(0.5, 1.0, 'lien entre le classement du bonheur et celui du HDI')
